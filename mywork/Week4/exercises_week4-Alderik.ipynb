# %% [markdown]
# # Week 4: Machine learning 1

# %% [markdown]
# Machine learning is a technique for learning patterns in data that enable computers to make decisions and predictions. It's probably one of the hottest skills to master as a scientist or engineer in research or industry today. This week, we'll get an overview of what machine learning is, what it can be used for and what its limits are. Without worrying too much about what goes on behind the scenes, we will play around with a few classifiers in Python and test model performance using cross validation. The exercises today cover:
#
# * Feature representation
# * Model fitting
# * Model evaluation
# * Prediction results
#
# [**Feedback**](http://ulfaslak.com/vent)

# %% [markdown]
# ## Exercises

# %% [markdown]
# We want to predict whether a character is a hero or a villain from information that we can extract from their markup. This is a large problem that includes some data wrangling, model fitting and a bit of evaluation. Therefore the problem is split into parts.

# %% [markdown]
# ### Part 1: Feature representation
# In it's raw format, the data cannot be given to a machine learning algorithm. What we must do is extract features from the data and put them into a structured format. This is the same as what we did when we looked at a dog (the data) and extracted into a matrix whether it was fluffy, sad looking, etc. (the features). The feature we will extract here is **team alliances**.
#
# We can represent the team alliances of each character as a row in a matrix where each column corresponds to a particular team. That should look something like this (numbers are made up):
#
# <img src="http://ulfaslak.com/computational_analysis_of_big_data/exer_figures/example_boa.png" width="400"/>
#
# **Note**: The following exercises relies on the dataset you produced in Ex. 3.1.2 (character markup stored on your computer). If you didn't manage to produce the dataset [use mine](http://github.com/ulfaslak/caobd_s19/tree/master/data) and go back and complete it at a later time so that you get the most out of this session.

# %% [markdown]
# > **Ex.4.1.1**: Write a function called `get_alliances` that takes the name of a character and returns a list of teams that the character is allied with. Print the alliances of Iron Man.
#
# *Hint: There is a place in the character markup where you'll find the team affiliations and you want to write some code that can extract that. The affiliations are not always listed the same way so you should probably try to eyeball some of the documents to get a feel of how the formatting can look.*

# %%
import re, os

def get_alliances(char, faction=None):
    """Return list of alliances for Marvel character."""
    
    if faction is None:
        for faction in ["heroes", "ambiguous", "villains"]:
            faction_chars = [c[:-4] for c in os.listdir("/Users/alderik/Documents/School/College/DIS/bigdata/caobd_f19/data/%s" % faction)]
            if char in faction_chars:
                break
    
    # Load character markup
    with open("/Users/alderik/Documents/School/College/DIS/bigdata/caobd_f19/data/%s/%s.txt" % (faction, char)) as fp:
        markup = fp.read()

    # Get alliance field
    alliances_field = re.findall(r"alliances[\w\W]+?\|.+=", markup)
    if alliances_field == []:
        return []

    # Extract teams from alliance field
    return [t[2:-1] for t in re.findall(r"\[\[.+?[\]\|]", alliances_field[0][10:])]

# %%
get_alliances("Iron Man")
# Out:
# ['Avengers (comics)',
#  'United States Department of Defense',
#  'Force Works',
#  'The New Avengers (comics)',
#  'Guardians of the Galaxy (2008 team)',
#  'Illuminati (comics)',
#  'The Mighty Avengers',
#  'S.H.I.E.L.D.',
#  'Stark Industries',
#  'Stark Resilient',
#  'Thunderbolts (comics)']

# %% [markdown]
# > **Ex.4.1.2**: Produce a sorted list called `all_teams` that contains all teams in the entire Marvel universe. Print the first 10.

# %%
def get_universe():
    directory = "/Users/alderik/Documents/School/College/DIS/bigdata/caobd_f19/data/"
    marvel_universe = []
    for faction in ["heroes", "ambiguous", "villains"]:
        faction_chars = [c[:-4] for c in os.listdir("/Users/alderik/Documents/School/College/DIS/bigdata/caobd_f19/data/%s" % faction)]
        for i in faction_chars:
            marvel_universe.append(i)
            
    marvel_universe.sort()
    return marvel_universe

# %%
def get_teams():
    """Returns list of all teams"""
    all_teams = []
    
    chars = get_universe()
    for i in chars:
        teams = get_alliances(i)
        while len(teams)>0:
            if teams[0] not in all_teams:
                all_teams.append(teams[0])
                teams.remove(teams[0])
            else:
                teams.remove(teams[0])
    
    all_teams.sort()
    return all_teams

# %%
ans = get_teams()
ans
# Out:
# ['A-Force',
#  'A-Next',
#  'A.R.M.O.R.',
#  'AXIS (comics)',
#  'Acolytes (comics)',
#  'Acts of Vengeance',
#  'Advanced Idea Mechanics',
#  'Advanced Idea Mechanics#Avengers Idea Mechanics',
#  'Age of Apocalypse',
#  'Agency X',
#  'Agent X (Marvel Comics)',
#  'Agents of Atlas',
#  'Agents of Fortune (comics)',
#  'Alchemax',
#  'Alias (comics)',
#  'All-New X-Factor',
#  'All-New X-Men',
#  'All-New, All-Different Avengers',
#  'All-Winners Squad',
#  'Alliance of Evil',
#  'Alliance of Evil (comics)',
#  'Alpha Flight',
#  'Alpha Squadron (comics)',
#  'Amazons',
#  'America Redeemers',
#  'Anachronauts (comics)',
#  'Ani-Men',
#  'Annihilation (comics)',
#  'Annihilators (Marvel Comics)',
#  'Apocalypse (comics)',
#  'Apocalypse: The Twelve',
#  'Argonauts',
#  'Art Thibert',
#  'Arthur Adams (comics)',
#  'Asgard (comics)',
#  'Askani',
#  'Astronaut',
#  'Atlantis (Marvel Comics)',
#  'Attuma',
#  'Avengers (comics)',
#  'Avengers 1959',
#  'Avengers A.I.',
#  'Avengers Academy',
#  'Avengers West Coast',
#  'Avengers: The Initiative',
#  'Avengers: The Initiative#Shadow Initiative',
#  'BAD Girls, Inc.',
#  'Bacchae (comics)',
#  'Badoon',
#  'Bandit (comics)',
#  'Batroc the Leaper',
#  "Batroc's Brigade",
#  'Bendis, Brian Michael',
#  'Beta Flight',
#  'Beyonders',
#  'Big Hero 6 (comics)',
#  'Black Air',
#  'Black Order (comics)',
#  'Black Spectre',
#  'Black Spectre#Black Spectre (organization)',
#  'Blade (comics)',
#  'British Army',
#  'British army',
#  'Brood (comics)',
#  'Brotherhood of Evil Mutants',
#  'Brotherhood of Mutants',
#  'Brotherhood of Mutants#Sisterhood of Mutants',
#  'Brotherhood of Mutants#Ultimate Brotherhood',
#  'Cabal (comics)',
#  'Camelot',
#  'Captain Britain Corps',
#  'Cat People (comics)',
#  'Centers for Disease Control',
#  'Central Intelligence Agency',
#  'Champions (1975 team)',
#  'Champions (2016 team)',
#  'Champions of Xandar',
#  'Chaos War (comics)',
#  'Charles Xavier',
#  'Cheyarafim',
#  'Children of the Vault',
#  'Chitauri',
#  'Church of Hala',
#  'Circus of Crime',
#  'Civil War (comics)',
#  'Clan Akkaba',
#  'Clan Chosen',
#  'Code: Blue',
#  'Commission on Superhuman Activities',
#  'Committee (comics)',
#  'Conspiracy (comics)',
#  'Corporation (comics)',
#  'Council of God-Heads',
#  'Counter Force (Marvel Comics)',
#  'Crazy Gang (Marvel Comics)',
#  'Crazy Gang (comics)',
#  'Cross Technological Enterprises',
#  'Crusaders (Marvel Comics)',
#  'Crusades',
#  'Cult of Kali',
#  'Cypher (comics)',
#  'DARPA',
#  'Daily Bugle',
#  'Damage Control (comics)',
#  'Dark Avengers',
#  'Dark Illuminati',
#  'Dark Riders (comics)',
#  'Dark X-Men',
#  'Darkhold',
#  'Daughters of the Dragon',
#  'David Marquez (comics)',
#  'Deadpool',
#  'Deadpool Corps',
#  'Death Squad (comics)',
#  "Death Squad (comics)#Black Lama's Death Squad",
#  'Death-Throws',
#  'Deep Six (Marvel Comics)',
#  "Deep Six (Marvel Comics)#Namor's Deep Six",
#  'Defenders (comics)',
#  'Defenders (comics)#"Defenders for a Day"',
#  'Defenders (comics)#Defenders 2099',
#  'Defenders (comics)#Secret Defenders',
#  'Defenders (comics)#The Last Defenders',
#  'Defenders (comics)#The Offenders',
#  'Department H',
#  'Desert Stars',
#  'Desert Sword',
#  'Deviant (comics)',
#  'Doctor Strange',
#  'Dora Milaje',
#  'Dr. Octopus',
#  'Drain Dwellers',
#  'Dream Team (comics)',
#  'Drug Enforcement Administration',
#  'Edwin Cord',
#  'Elder Gods (Marvel Comics)',
#  'Elders of the Universe',
#  'Emissaries of Evil',
#  'Empire State University',
#  'Enforcers (comics)',
#  'Eternal (comics)',
#  'Eternals (comics)',
#  'Excalibur (comics)',
#  'Excalibur (comics)#New Excalibur (2005)',
#  'Excalibur (comics)#New Excalibur (2005–2007)',
#  'Exiles (Malibu Comics)',
#  'Exiles (Marvel Comics)',
#  'Exiles (Red Skull allies)',
#  'Exterminators (comics)',
#  'Externals',
#  'FBI',
#  'FLQ',
#  'Factor Three',
#  'Fallen Angels (comics)',
#  'Fantastic Five',
#  'Fantastic Force',
#  'Fantastic Four',
#  'Fantastic Four Incorporated',
#  'Fear Itself (comics)',
#  'Fear Lords (comics)',
#  'Fearless Defenders',
#  'Fearsome Foursome (comics)',
#  'Federal Bureau of Investigation',
#  'Federal government of the United States',
#  'Fellowship of Fear',
#  'Femizons',
#  'Femme Fatales (comics)',
#  'Fifty State Initiative',
#  'Fin Fang Four',
#  'Firm (comics)',
#  'First Line (comics)',
#  'Flashmob (comics)',
#  'Folding Circle',
#  'Force Works',
#  'Force of Nature (comics)',
#  'Freaks (Marvel Comics)',
#  'Frederick Foswell',
#  'Freedom Force (comics)',
#  'Freedom Force (comics)#Initiative Freedom Force',
#  "Freedom's Five",
#  'Freelance Restorations',
#  'French Foreign Legion',
#  'Friends of Humanity',
#  'Frightful Four',
#  'Future Foundation',
#  'G.B. Blackrock',
#  'Galactic Council',
#  'Galactic Guardians',
#  'Galactus#Herald',
#  'Gamma Corps',
#  'Gamma Flight',
#  'Gene Nation',
#  'Generation Hope (comics)',
#  'Generation X (comics)',
#  'Genetix (comics)',
#  'Genosha',
#  'Gladiators (comics)',
#  'Goblin (Marvel Comics)',
#  'God Squad (comics)',
#  'Godzilla (comics)#Marvel Comics',
#  'Goodman, Lieber, Kurtzberg & Holliway',
#  'Grapplers (comics)',
#  'Great Lakes Avengers',
#  'Green Goblin',
#  'Guardians of the Galaxy',
#  'Guardians of the Galaxy (1969 team)',
#  'Guardians of the Galaxy (2008 team)',
#  'Guardsman (comics)',
#  'H.A.M.M.E.R.',
#  'H.A.T.E.',
#  'HYDRA (comics)',
#  'Hammer Industries',
#  'Hand (comics)',
#  'Hardcore (comics)',
#  'Headmen',
#  'Heavy Hitters (comics)',
#  'Heavy Metal (Marvel Comics)',
#  'Heavy Mettle',
#  "Hell's Belles",
#  'Hell-lords',
#  'Hellfire Club (comics)',
#  'Hellfire Club (comics)#Hellfire Academy',
#  'Hellions (Marvel Comics)',
#  'Herald of Galactus',
#  'Heroes for Hire',
#  'Heroes for Hire#Heroes for Hire (2006)',
#  'Holy See',
#  'Hood (comics)',
#  'Hope Summers (comics)#Generation Hope',
#  'Horseman of Apocalypse',
#  'Horsemen of Apocalypse',
#  'Hounds (comics)',
#  'Howling Commandos',
#  'Howling Commandos#Howling Commandos of S.H.I.E.L.D.',
#  'Hulkbusters',
#  "Humanity's Last Stand",
#  'Hydra (Marvel Comics)',
#  'Hydra (comics)',
#  'Illuminati (comics)',
#  'Immortal Weapons',
#  'Imperfects',
#  'Imperial Guard (comics)',
#  'Imperial Japanese Army',
#  'Indian Police Service',
#  'Infinity Watch',
#  'Inheritors (comics)',
#  'Inhuman Royal Family',
#  'Inhumans',
#  'Initiative (comics)',
#  'Inner Guard (comics)',
#  'Institute of Evil',
#  'Intelligencia (comics)',
#  'Interpol',
#  'Inuit',
#  'Invaders (comics)',
#  'J. Jonah Jameson',
#  'Juggernaut (comics)',
#  'KGB',
#  'Kang the Conqueror',
#  'Karma (comics)',
#  'Kid Commandos',
#  'Klaw (Marvel Comics)',
#  'Knights of Pendragon',
#  'Kree',
#  'Kronas Corporation',
#  'Lady Liberators',
#  'Lady Liberators (comics)',
#  "Lady Liberators (comics)#She-Hulk's team",
#  'Landau, Luckman, and Lake',
#  'Legion Accursed',
#  'Legion of Losers',
#  'Legion of Monsters',
#  'Legion of Night',
#  'Legion of the Unliving',
#  'Lemuria (comics)',
#  'Lethal Legion',
#  'Liberty Legion',
#  'Liberty Legion#Liberteens (2007)',
#  'List of Avengers members#Astonishing Avengers (2014)',
#  "List of Avengers members#Fury's Black Ops Initiative (1959)",
#  'List of Fantastic Four members',
#  'List of Marvel Comics demons#Fear Lords',
#  'List of Marvel Comics demons#The Hell-lords',
#  'List of X-Men members#Genoshan Assault X-Men (2001)',
#  'List of X-Men members#Muir Island X-Men (1989)',
#  'List of X-Men members#Other student squads (2003–2006)',
#  'List of X-Men members#Street Team X-Men (2004)',
#  'List of X-Men members#X-Men-In-Training (2006-present)',
#  'List of X-Men members#X-Men-In-Training (2006–present)',
#  'List of Xavier Institute students and staff#Jean Grey School for Higher Learning',
#  'List of Xavier Institute students and staff#New Charles Xavier School for Mutants#Students',
#  'List of Xavier Institute students and staff#Students',
#  'List of alien races in Marvel Comics#P',
#  'Lockjaw and the Pet Avengers',
#  'Loners',
#  'Loners (comics)',
#  'Lords of the Splinter Realms',
#  'MI-13 (Marvel Comics)',
#  'MI-13 (comics)',
#  'MI16',
#  'MI5',
#  'MI6',
#  'MODOK',
#  'Madripoor',
#  'Maggia (comics)',
#  'Maggia (comics)#The Costa Family',
#  'Magistrates (comics)',
#  "Mandarin's Minions",
#  'Marauders (comics)',
#  'Marvel Knights',
#  'Marvel Knights#Marvel Knights as a team',
#  'Marvel Knights#Team',
#  'Marvel Super Hero Contest of Champions',
#  'Masters of Evil',
#  "Masters of Evil#Max Fury's Masters of Evil",
#  'Maximum Carnage',
#  'Mercs for Money',
#  'Micronauts (comics)',
#  'Midnight Sons',
#  'Mighty Avengers',
#  'Mighty Avengers (comics)',
#  'Mindless Ones',
#  'Mister X (Marvel Comics)',
#  'Monster Hunters',
#  'Morlocks (comics)',
#  'Mossad',
#  'Mutant Force',
#  'Mutant Liberation Front',
#  'Mutant Underground',
#  'Mutant X (comics)',
#  "N'astirh",
#  'NASA',
#  'NATO',
#  'NSA',
#  'NYPD',
#  'Nanny (comics)',
#  'Nasty Boys',
#  'National Force',
#  'Nazi Germany',
#  'Nazi Party',
#  'Negative Zone',
#  'Neo-Knights',
#  'New Avengers (comic)',
#  'New Avengers (comics)',
#  'New Canaanites',
#  'New Enforcers',
#  'New Excalibur',
#  'New Fantastic Four',
#  'New Invaders',
#  'New Men (Marvel Comics)',
#  'New Mutants',
#  'New Mutants#The New Mutants, vol. 2',
#  'New U Technologies',
#  'New Warriors',
#  'New Warriors#Alternate versions',
#  'New Warriors#New Warriors (vol. 5)',
#  'New X-Men',
#  'New York City',
#  'New York City Police Department',
#  'New York Police Department',
#  'Nextwave',
#  'Neyaphem',
#  "Nick Fury's Howling Commandos",
#  'Night People (comics)',
#  'Night Shift (comics)',
#  'Night Thrasher',
#  'Nightstalkers (comics)',
#  'Norman Osborn',
#  'Nova Corps',
#  'Office of National Emergency',
#  'Official Handbook of the Marvel Universe A to Z',
#  'Olympians (Marvel Comics)',
#  'Olympians (comics)',
#  'Omega Flight',
#  'Omega Flight#Canadian superhero team',
#  'Omega Gang',
#  'Operation: Zero Tolerance',
#  'Oscorp',
#  'Outcasts (Marvel Comics Subterranea)',
#  'Pacific Overlords',
#  'Pantheon (Marvel Comics)',
#  'Paragons (comics)',
#  'Parker Industries',
#  'Parliament of the United Kingdom',
#  "People's Defense Force",
#  "People's Protectorate",
#  "People's Republic of China",
#  'Phalanx (comics)',
#  'Phoenix Force (comics)#Avengers vs. X-Men',
#  'Point Men',
#  'Power Pack',
#  'Power Tools (comics)',
#  'Press Gang (comics)',
#  'Pride (comics)',
#  'Prime Sentinel',
#  'Project Pegasus',
#  'Project Wideawake',
#  'Providence (comics)',
#  'Psi-Key',
#  'Psionex',
#  'Purifiers (Marvel Comics)',
#  'R.C.X.',
#  'Rangers (comics)',
#  'Reavers (comics)',
#  'Red Mafia',
#  'Redeemers (comics)',
#  'Resistants',
#  'Revengers',
#  'Revengers#Earth-616',
#  'Right (comics)',
#  'Riot Squad (comics)',
#  'Roman Catholic Archdiocese of New York',
#  'Roman Senate',
#  'Roxxon',
#  'Roxxon Energy Corporation',
#  'Roxxon Oil',
#  'Roxxon Oil Company',
#  'Royal Canadian Mounted Police',
#  'Runaways (comics)',
#  'Russia',
#  'S.H.I.E.L.D',
#  'S.H.I.E.L.D.',
#  'S.H.I.E.L.D.#Ultimate S.H.I.E.L.D.',
#  'S.T.A.K.E.',
#  'S.W.O.R.D. (comics)',
#  'SS-Oberführer',
#  "Salem's Seven",
#  'Sapien League',
#  'Satan Squad',
#  'Savage Land Mutates',
#  'Savage Six',
#  'Schutz Heiliggruppe',
#  'Scourges of the Underworld',
#  'Secret Avengers',
#  'Secret Defenders',
#  'Secret Empire (comics)',
#  'Secret Empire (organization)',
#  'Secret Intelligence Service',
#  'Secret Warriors (2017 series)',
#  'Secret Warriors (Team White)',
#  'Selene (comics)',
#  'Sentinel (comics)',
#  'Sentinels (comics)',
#  'Serpent Society',
#  'Serpent Squad',
#  'Set (serpent god)',
#  'Sgt. Fury and his Howling Commandos',
#  'Shadow Council',
#  'Shadow Initiative',
#  'Shadow-X',
#  'She-Hulk#Fearsome Four',
#  "Shi'ar",
#  "Shi'ar Imperial Guard",
#  'Sinister Six',
#  'Sinister Six#Sinister Twelve',
#  'Sinister Sixteen',
#  'Sinister Syndicate',
#  'Sinister Twelve',
#  'Siryn (comics)',
#  'Sisters of Sin',
#  'Six Pack (comics)',
#  'Skeleton Crew (comics)',
#  'Skrull',
#  'Skrull Kill Krew',
#  'Skrull#Fall of the Skrull Empire',
#  'Slingers (Marvel Comics)',
#  'Sons of Yinsen',
#  'Sons of the Tiger',
#  'Soviet Super-Soldiers',
#  'Soviet Super-Troopers',
#  'Spaceknights',
#  'Spider-Man',
#  'Spider-Verse',
#  'Spider-Verse#Secret Wars (2015)',
#  'Spider-Verse#Web-Warriors',
#  'Squadron Sinister',
#  'Squadron Supreme',
#  'Squadron Supreme (Supreme Power)',
#  'Starforce (comics)',
#  'Starjammers',
#  'Stark Industries',
#  'Stark Resilient',
#  'Strikeforce: Morituri',
#  'Subterranea (comics)',
#  'Super-Axis',
#  'Super-Sentinels',
#  'Superior Spider-Man',
#  'Supernova (Marvel Comics)',
#  'Supreme Intelligence',
#  'Supreme Power',
#  'Supreme Soviets',
#  'Symbiote (comics)',
#  'Team X (comics)',
#  'Technarchy',
#  'Teen Brigade',
#  'The 198',
#  'The Champions',
#  'The Chaste',
#  'The Children (comics)',
#  'The Crew (comics)',
#  'The Hand (comics)',
#  'The Intruders (comics)',
#  'The Jury (comics)',
#  'The Last Defenders',
#  'The Mighty Avengers',
#  'The New Avengers (comic)',
#  'The New Avengers (comics)',
#  'The Order (comics)',
#  'The Order (comics)#Defenders offshoot',
#  'The Outlaws (comics)',
#  'The Pulse (comics)',
#  'The Right (comics)',
#  'The Spider Society',
#  'The Transformers (Marvel Comics)',
#  'The Twelve (comics)',
#  'The Ultimates',
#  'Theatre of Pain',
#  "Thieves' guild",
#  'Thor Corps',
#  'Thunderbolts (comic)',
#  'Thunderbolts (comics)',
#  'Thunderiders',
#  'Titanic Three',
#  'Tong (organization)',
#  'Triad (underground society)',
#  'Triune Understanding',
#  'U-Foes',
#  'U-Men (comics)',
#  'U.S. Air Force',
#  'U.S. Army',
#  'U.S. military',
#  'U.S.Avengers',
#  'ULTIMATUM (comics)',
#  'US Military',
#  'Ultimate Comics: New Ultimates',
#  'Ultimate Fantastic Four',
#  'Ultimates',
#  'Ultimates (2015 team)',
#  'Ultraforce (comics)',
#  'Uncanny Avengers',
#  'Uncanny X-Force',
#  'United Front (comics)',
#  'United Nations',
#  'United States Air Force',
#  'United States Army',
#  'United States Department of Defense',
#  'United States Marine Corps',
#  'United States Navy',
#  'Universal Inhumans',
#  'Unlimited Class Wrestling Federation',
#  'Upstarts (comics)',
#  'V-Battalion',
#  'Valkyrior',
#  'Valkyrior (Marvel Comics)',
#  'Vampire (Marvel Comics)',
#  'Vanguard (Marvel Comics)#Vanguard',
#  'Venomverse',
#  'Villains for Hire',
#  'Viper (Marvel Comics)',
#  'Walt Simonson',
#  'Warbound',
#  'Warriors Three',
#  'Weapon P.R.I.M.E.',
#  'Weapon Plus',
#  'Weapon Plus#Weapon I',
#  'Weapon Plus#Weapon VII',
#  'Weapon X',
#  'Weapon X#Fourth installment',
#  'Weapon X#Second installment',
#  'Weapon X#The Facility',
#  'West Coast Avengers',
#  'Wild Pack',
#  'Wild Pack#Intruders',
#  'Williams Innovations',
#  'Winter Guard',
#  'Witches (Marvel Comics)',
#  'Wolverine and the X-Men (comics)',
#  "Women's Army Corps",
#  'World Counter-terrorism Agency',
#  'World War Hulk',
#  'Wrecking Crew (comics)',
#  'X-Club (comics)',
#  'X-Corporation',
#  'X-Corps',
#  'X-Factor (comics)',
#  'X-Factor Investigations',
#  'X-Force',
#  'X-Force (comics)',
#  'X-Mansion',
#  'X-Mansion#Post X-Men: Schism',
#  'X-Men',
#  'X-Men (comics)',
#  'X-Men 2099',
#  'X-Men Blue',
#  'X-Men Red',
#  'X-Men: The 198',
#  'X-Nation 2099',
#  'X-People',
#  'X-Statix',
#  'X-Terminators',
#  'X-Treme Sanctions Executive',
#  'X-Treme X-Men',
#  'X-Treme X-Men#Volume 1',
#  'X-Treme X-Men#Volume 2',
#  'X.S.E',
#  'Xavier Institute',
#  'Xavier Institute Student Body#Corsairs',
#  'Xavier Institute student body',
#  'Xavier Security Enforcers',
#  "Xavier's Security Enforcers",
#  "Xavier's Underground Enforcers",
#  'Yakuza',
#  'Yancy Street Gang',
#  'Young Allies',
#  'Young Allies (Marvel Comics)',
#  'Young Allies (Marvel Comics)#Counter-Earth',
#  'Young Allies (Marvel Comics)#Heroes Reborn',
#  'Young Allies (Marvel Comics)#Heroic Age',
#  'Young Avengers',
#  'Young Masters',
#  'Young X-Men',
#  'Zodiac (comics)']

# %% [markdown]
# > **Ex.4.1.3**: Write a function that takes the name of a character and returns a vector representation of the team alliances for that character. The length of the returned list will be `len(all_teams)` and have 0s in the places corresponding to teams that the character is not on, and 1s in the places corresponding to teams the character is on. Print the sum of the list returned when the input to the function is Iron man.

# %%
def get_vector(char):
    faction = None
    char_alliances = get_alliances(char, faction)
    all_teams = get_teams()
    
    alliance_vector = []
    for i in all_teams:
        count = 0
        for j in char_alliances:
            if i==j:
                count=1
                alliance_vector.append(count)
        alliance_vector.append(count)
        
    return alliance_vector

# %%
sum(get_vector('Iron Man'))
# Out:
# 22

# %% [markdown]
# > **Ex. 4.1.4**: Create the team alliance matrix for the data. This is your feature matrix for the classification problem you will solve later in this exercise set. Therefore, you should also—in a seperate *target* array—store whether characters are heros (denote by 1) or villains (denote by 0). For now, skip ambiguous characters, but write your code in such a way that it won't be too hard to redo this for ambiguous characters. Skip characters that have no team alliances. Print the shapes of your matrix and target array.

# %%
import pandas as pd
def get_vector_quick(char, all_teams):
    faction = None
    char_alliances = get_alliances(char, faction)
    alliance_vector = []
    for i in all_teams:
        count = 0
        for j in char_alliances:
            if i==j:
                count=1
                alliance_vector.append(count)
            else:
                alliance_vector.append(count)
        
    return alliance_vector

def get_vector_quick(char, all_teams):
    faction = None
    char_alliances = get_alliances(char, faction)
    alliance_vector = []
    for team in all_teams:
        if team in char_alliances:
            alliance_vector.append(1)
        else:
            alliance_vector.append(0)
    return alliance_vector

def get_matrix():
    all_chars = get_universe()
    all_teams = get_teams()
    char_vecs = []
    
    for i in all_chars:
        char_vecs.append(get_vector_quick(i,all_teams))
        
    return char_vecs

# %%
char_alliance_vec = get_matrix()
all_teams = get_teams()
all_chars = get_universe()
df = pd.DataFrame(char_alliance_vec, columns=all_teams, index=all_chars) 
df
# Out:
#                               A-Force  A-Next  A.R.M.O.R.  AXIS (comics)  \
# Abigail Brand                       0       0           0              0
# Abner Jenkins                       0       0           0              0
# Abomination (comics)                0       0           0              0
# Abraham Cornelius                   0       0           0              0
# Absalom (comics)                    0       0           0              0
# Absorbing Man                       0       0           0              0
# Abyss (comics)                      0       0           0              0
# Achilles (Pantheon)                 0       0           0              0
# Acrobat (comics)                    0       0           0              0
# Adam II                             0       0           0              0
# Adam Warlock                        0       0           0              0
# Adam X the X-Treme                  0       0           0              0
# Adept (comics)                      0       0           0              0
# Adria (comics)                      0       0           0              0
# Adrienne Frost                      0       0           0              0
# Adversary (comics)                  0       0           0              0
# Advisor (comics)                    0       0           0              0
# Aftershock (comics)                 0       0           0              0
# Agent (comics)                      0       0           0              0
# Agent X (Marvel Comics)             0       0           0              0
# Aguja                               0       0           0              0
# Ahab (comics)                       0       0           0              0
# Ahura (comics)                      0       0           0              0
# Aikku Jokinen                       0       0           0              0
# Air-Walker                          0       0           0              0
# Ajaxis                              0       0           0              0
# Al MacKenzie                        0       0           0              0
# Al-Tariq                            0       0           0              0
# Alaris (comics)                     0       0           0              0
# Albino (comics)                     0       0           0              0
# ...                               ...     ...         ...            ...
# Wulff (comics)                      0       0           0              0
# Wundarr the Aquarian                0       0           0              0
# X-23                                0       0           0              0
# X-Ray (comics)                      0       0           0              0
# Xarus                               0       0           0              0
# Xavin                               0       0           0              0
# Xemu (comics)                       0       0           0              0
# Xenophage (comics)                  0       0           0              0
# Xorn                                0       0           0              0
# Xorr the God-Jewel                  0       0           0              0
# Adam Warlock                                        0
# Adam X the X-Treme                                  0
# Adept (comics)                                      0
# Adria (comics)                                      0
# Adrienne Frost                                      0
# Adversary (comics)                                  0
# Advisor (comics)                                    0
# Aftershock (comics)                                 0
# Agent (comics)                                      0
# Agent X (Marvel Comics)                             0
# Aguja                                               0
# Ahab (comics)                                       0
# Ahura (comics)                                      0
# Aikku Jokinen                                       0
# Air-Walker                                          0
# Ajaxis                                              0
# Al MacKenzie                                        0
# Al-Tariq                                            0
# Alaris (comics)                                     0
# Albino (comics)                                     0
# ...                                               ...
# Wulff (comics)                                      0
# Wundarr the Aquarian                                0
# X-23                                                0
# X-Ray (comics)                                      0
# Xarus                                               0
# Xavin                                               0
# Xemu (comics)                                       0
# Xenophage (comics)                                  0
# Xorn                                                0
# Xorr the God-Jewel                                  0
# Y'Garon                                             0
# Yandroth                                            0
# Yellowjacket (Marvel Comics)                        0
# Yellowjacket (Rita DeMara)                          0
# Yidrazil (comics)                                   0
# Ymir (Marvel Comics)                                0
# Yo-Yo Rodriguez                                     0
# Yon-Rogg                                            0
# Yondu                                               0
# Yukio (comics)                                      0
# Yukon Jack                                          0
# Zarathos                                            0
# Zarek (comics)                                      0
# Zarrko                                              0
# Zeke Stane                                          0
# Zodiak (comics)                                     0
# Zombie (comics)                                     0
# Zota                                                0
# Zvezda Dennista                                     0
# Zzzax                                               0
#
#                               Advanced Idea Mechanics#Avengers Idea Mechanics  \
# Abigail Brand                                                               0
# Abner Jenkins                                                               0
# Abomination (comics)                                                        0
# Abraham Cornelius                                                           0
# Absalom (comics)                                                            0
# Absorbing Man                                                               0
# Abyss (comics)                                                              0
# Achilles (Pantheon)                                                         0
# Acrobat (comics)                                                            0
# Adam II                                                                     0
# Adam Warlock                                                                0
# Adam X the X-Treme                                                          0
# Adept (comics)                                                              0
# Adria (comics)                                                              0
# Adrienne Frost                                                              0
# Adversary (comics)                                                          0
# Advisor (comics)                                                            0
# Aftershock (comics)                                                         0
# Agent (comics)                                                              0
# Agent X (Marvel Comics)                                                     0
# Aguja                                                                       0
# Ahab (comics)                                                               0
# Ahura (comics)                                                              0
# Aikku Jokinen                                                               1
# Air-Walker                                                                  0
# Ajaxis                                                                      0
# Al MacKenzie                                                                0
# Al-Tariq                                                                    0
# Alaris (comics)                                                             0
# Albino (comics)                                                             0
# ...                                                                       ...
# Wulff (comics)                                                              0
# Wundarr the Aquarian                                                        0
# X-23                                                                        0
# X-Ray (comics)                                                              0
# Xarus                                                                       0
# Xavin                                                                       0
# Xemu (comics)                                                               0
# Xenophage (comics)                                                          0
# Xorn                                                                        0
# Xorr the God-Jewel                                                          0
# Y'Garon                                                                     0
# Yandroth                                                                    0
# Yellowjacket (Marvel Comics)                                                0
# Yellowjacket (Rita DeMara)                                                  0
# Yidrazil (comics)                                                           0
# Ymir (Marvel Comics)                                                        0
# Yo-Yo Rodriguez                                                             0
# Yon-Rogg                                                                    0
# Yondu                                                                       0
# Yukio (comics)                                                              0
# Yukon Jack                                                                  0
# Zarathos                                                                    0
# Zarek (comics)                                                              0
# Zarrko                                                                      0
# Zeke Stane                                                                  0
# Zodiak (comics)                                                             0
# Zombie (comics)                                                             0
# Zota                                                                        0
# Zvezda Dennista                                                             0
# Zzzax                                                                       0
#
#                               Age of Apocalypse  Agency X  ...  \
# Abigail Brand                                 0         0  ...
# Abner Jenkins                                 0         0  ...
# Abomination (comics)                          0         0  ...
# Abraham Cornelius                             0         0  ...
# Absalom (comics)                              0         0  ...
# Absorbing Man                                 0         0  ...
# Abyss (comics)                                0         0  ...
# Achilles (Pantheon)                           0         0  ...
# Acrobat (comics)                              0         0  ...
# Adam II                                       0         0  ...
# Adam Warlock                                  0         0  ...
# Adam X the X-Treme                            0         0  ...
# Adept (comics)                                0         0  ...
# Adria (comics)                                0         0  ...
# Adrienne Frost                                0         0  ...
# Adversary (comics)                            0         0  ...
# Advisor (comics)                              0         0  ...
# Aftershock (comics)                           0         0  ...
# Agent (comics)                                0         0  ...
# Agent X (Marvel Comics)                       0         0  ...
# Aguja                                         0         0  ...
# Ahab (comics)                                 0         0  ...
# Ahura (comics)                                0         0  ...
# Aikku Jokinen                                 0         0  ...
# Air-Walker                                    0         0  ...
# Ajaxis                                        0         0  ...
# Al MacKenzie                                  0         0  ...
# Al-Tariq                                      0         0  ...
# Alaris (comics)                               0         0  ...
# Albino (comics)                               0         0  ...
# ...                                         ...       ...  ...
# Wulff (comics)                                0         0  ...
# Wundarr the Aquarian                          0         0  ...
# X-23                                          0         0  ...
# X-Ray (comics)                                0         0  ...
# Xarus                                         0         0  ...
# Xavin                                         0         0  ...
# Xemu (comics)                                 0         0  ...
# Xenophage (comics)                            0         0  ...
# Xorn                                          0         0  ...
# Xorr the God-Jewel                            0         0  ...
# Y'Garon                                       0         0  ...
# Yandroth                                      0         0  ...
# Yellowjacket (Marvel Comics)                  0         0  ...
# Yellowjacket (Rita DeMara)                    0         0  ...
# Yidrazil (comics)                             0         0  ...
# Ymir (Marvel Comics)                          0         0  ...
# Yo-Yo Rodriguez                               0         0  ...
# Yon-Rogg                                      0         0  ...
# Yondu                                         0         0  ...
# Yukio (comics)                                0         0  ...
# Yukon Jack                                    0         0  ...
# Zarathos                                      0         0  ...
# Zarek (comics)                                0         0  ...
# Zarrko                                        0         0  ...
# Zeke Stane                                    0         0  ...
# Zodiak (comics)                               0         0  ...
# Zombie (comics)                               0         0  ...
# Zota                                          0         0  ...
# Zvezda Dennista                               0         0  ...
# Zzzax                                         0         0  ...
#
#                               Yancy Street Gang  Young Allies  \
# Abigail Brand                                 0             0
# Abner Jenkins                                 0             0
# Abomination (comics)                          0             0
# Abraham Cornelius                             0             0
# Absalom (comics)                              0             0
# Absorbing Man                                 0             0
# Abyss (comics)                                0             0
# Achilles (Pantheon)                           0             0
# Acrobat (comics)                              0             0
# Adam II                                       0             0
# Adam Warlock                                  0             0
# Adam X the X-Treme                            0             0
# Adept (comics)                                0             0
# Adria (comics)                                0             0
# Adrienne Frost                                0             0
# Adversary (comics)                            0             0
# Advisor (comics)                              0             0
# Aftershock (comics)                           0             0
# Agent (comics)                                0             0
# Agent X (Marvel Comics)                       0             0
# Aguja                                      0              0            0
# Ahab (comics)                              0              0            0
# Ahura (comics)                             0              0            0
# Aikku Jokinen                              0              0            0
# Air-Walker                                 0              0            0
# Ajaxis                                     0              0            0
# Al MacKenzie                               0              0            0
# Al-Tariq                                   0              0            0
# Alaris (comics)                            0              0            0
# Albino (comics)                            0              0            0
# ...                                      ...            ...          ...
# Wulff (comics)                             0              0            0
# Wundarr the Aquarian                       0              0            0
# X-23                                       0              0            0
# X-Ray (comics)                             0              0            0
# Xarus                                      0              0            0
# Xavin                                      0              0            0
# Xemu (comics)                              0              0            0
# Xenophage (comics)                         0              0            0
# Xorn                                       0              0            0
# Xorr the God-Jewel                         0              0            0
# Y'Garon                                    0              0            0
# Yandroth                                   0              0            0
# Yellowjacket (Marvel Comics)               0              0            0
# Yellowjacket (Rita DeMara)                 0              0            0
# Yidrazil (comics)                          0              0            0
# Ymir (Marvel Comics)                       0              0            0
# Yo-Yo Rodriguez                            0              0            0
# Yon-Rogg                                   0              0            0
# Yondu                                      0              0            0
# Yukio (comics)                             0              0            0
# Yukon Jack                                 0              0            0
# Zarathos                                   0              0            0
# Zarek (comics)                             0              0            0
# Zarrko                                     0              0            0
# Zeke Stane                                 0              0            0
# Zodiak (comics)                            0              0            0
# Zombie (comics)                            0              0            0
# Zota                                       0              0            0
# Zvezda Dennista                            0              0            0
# Zzzax                                      0              0            0
#
#                               Zodiac (comics)
# Abigail Brand                               0
# Abner Jenkins                               0
# Abomination (comics)                        0
# Abraham Cornelius                           0
# Absalom (comics)                            0
# Absorbing Man                               0
# Abyss (comics)                              0
# Achilles (Pantheon)                         0
# Acrobat (comics)                            0
# Adam II                                     0
# Adam Warlock                                0
# Adam X the X-Treme                          0
# Adept (comics)                              0
# Adria (comics)                              0
# Adrienne Frost                              0
# Adversary (comics)                          0
# Advisor (comics)                            0
# Aftershock (comics)                         0
# Agent (comics)                              0
# Agent X (Marvel Comics)                     0
# Aguja                                       0
# Ahab (comics)                               0
# Ahura (comics)                              0
# Aikku Jokinen                               0
# Air-Walker                                  0
# Ajaxis                                      0
# Al MacKenzie                                0
# Al-Tariq                                    0
# Alaris (comics)                             0
# Albino (comics)                             0
# ...                                       ...
# Wulff (comics)                              0
# Wundarr the Aquarian                        0
# X-23                                        0
# X-Ray (comics)                              0
# Xarus                                       0
# Xavin                                       0
# Xemu (comics)                               0
# Xenophage (comics)                          0
# Xorn                                        0
# Xorr the God-Jewel                          0
# Y'Garon                                     0
# Yandroth                                    0
# Yellowjacket (Marvel Comics)                0
# Yellowjacket (Rita DeMara)                  0
# Yidrazil (comics)                           0
# Ymir (Marvel Comics)                        0
# Yo-Yo Rodriguez                             0
# Yon-Rogg                                    0
# Yondu                                       0
# Yukio (comics)                              0
# Yukon Jack                                  0
# Zarathos                                    0
# Zarek (comics)                              0
# Zarrko                                      0
# Zeke Stane                                  0
# Zodiak (comics)                             0
# Zombie (comics)                             0
# Zota                                        0
# Zvezda Dennista                             0
# Zzzax                                       0
#
# [1874 rows x 622 columns]

# %%
def get_faction(char):
    faction = None
    ans = ''
    if faction is None:
        for faction in ["heroes", "ambiguous", "villains"]:
            faction_chars = [c[:-4] for c in os.listdir("/Users/alderik/Documents/School/College/DIS/bigdata/caobd_f19/data/%s" % faction)]
            if char in faction_chars:
                ans = faction
                break
    return ans
    
def hero_vil_ambig_matrix():
    all_chars = get_universe()
    faction_id = []
    for i in all_chars:
        faction = get_faction(i)
        if faction =='villains':
            faction_id.append(1)
        elif faction =='heroes':
            faction_id.append(0)
        else:
            faction_id.append(2)
    return faction_id

# %%
target_array = hero_vil_ambig_matrix()
df['faction'] = target_array #adds column of factions

# %%
df_final = df[df.faction != 2]

# %% [markdown]
# ### Part 2: Model fitting

# %% [markdown]
# > **Ex. 4.2.1**: Train a classifier on all of your data and test its accuracy.
#
# >* If your team alliance matrix is `X_ta` and your target array is `y_ta` you can do this by instantiating a model like:
# >
#         from sklearn.naive_bayes import BernoulliNB
#         model = BernoulliNB()
#         model.fit(X_ta, y_ta)  # <--- This is the training/fitting/learning step
#
# > The `BernoulliNB` is a version of the Naive Bayes classifier which associates certain features with labels and asks what the probability of a label for a data point is given its features. You are free to use any other classifier if you want. Popular ones are trees, random forests, support vector machines, feed forward neural networks, logistic regression, and the list goes on. With `sklearn`, they are just as easy to employ as the `BernoulliNB` classifier.
#
#
# >1. Test the accuracy of your model. You can use the `.predict` method on the `model` object to get predictions for a matrix of data points. Report the accuracy of your model on the same data that you trained the model on, alongside the baseline accuracy of a "dumb" model that only guesses for the majority class.
#
# >2. Report the precision, recall and F1 scores, with respect to the minority class (heroes). `sklearn` has implementations that you can use if you are short for time. Extra credit for doing it using only basic linear algebra operations with `numpy`, though.

# %% [markdown]
# ### Part 3: Model evaluation

# %% [markdown]
# > **Ex. 4.3.1**: Investigate how well your model generalizes. You may have noticed that the performance seemed a little too good to be true in Ex 4.2.1.
# 1. Why did you get such a high accuracy in the previous exercise?
# 2. Split your data into a test and training set of equal size. Train the model only on the training set and report its accuracy and F1 scores (for both classes) on both the training and test sets.
# 3. Comment on the difference you observe.
#
# > *Hint: Watch out for unbalanced class proportions! You may want to randomly reorder the rows of your datapoints and target labels so your training and test sets have the same amount of heroes and villains.*

# %% [markdown]
# > **Ex. 4.3.2**: Implement cross validation. The performance of a classifier is strongly dependent on the amount of data it is trained on. In Ex. 4.3.1 you train it on only half of the data and test it on the other half. If you rerun that code multiple times, with random 50/50 partitions, you are gonna see a lot of uncertainty in performance. Cross validation solves this problem by training on a larger subset of the data and testing on a smaller one, and taking the average performance over K-folds of this process.
# 1. Implement cross validation over $K=10$ folds. For each fold you must record the training and test accuracies. In the end, visualize the distributions of test- and training accuracy as histograms in the same plot. It's important that you comment on the result.

# %% [markdown]
# ### Part 4: Predicting good vs. evil

# %% [markdown]
# >**Ex. 4.4.1**: Let's put our classifier to use!
# * Retrain your model on all of your data.
# * Create a team alliance representation of the ambiguous characters
# * Use the model the estimate the probability that each character is a villain (let's call this *villainness*). You can use the `.predict_proba` method on the model to get probability estimates rather than class assignments.
# * **Visualize the "heroness" distribution for all ambiguous characters**. Comment on the result.
